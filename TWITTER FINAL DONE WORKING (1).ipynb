# %%
from textblob import TextBlob
import sys, tweepy
from tweepy import API

from tweepy import OAuthHandler

## Imported the Twitter API and the TextBLob which is a library for processing data

consumer_key = "4vfkAV19HTl3MWsWzERGmqaut"
consumer_secret = "qVkhJPOgk2XCOqQIVKOwdp0JXR6A1hTwvG9UFW7FmrZrusRB8c"
access_tokens = "394085841-K4JCh60Ex3gkew4g4vuIhwqR3hU6GdYp5nxJ4bn4"
access_token_secret = "KI89AiZtN7jQm7W89CI37mguC5yzfTbyqYZqKdUOkfG4f"

## Inserted the Twitter unique keys from the devloper account


auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_tokens, access_token_secret)
api = tweepy.API(auth, wait_on_rate_limit=True)

## Called the API and initialized their value.


## Taking Input from the User.
search_term = input("Enter keyword to search about: ")
no_of_search_terms = int(input("Enter the number of tweets you want to analyze: "))

## Initialize the values.
positive = 0
negative = 0
neutral = 0
polarity = 0

# Call  the tweepy.

public_tweets = tweepy.Cursor(api.search, q=search_term).items(no_of_search_terms)


for tweet in public_tweets:
    print(tweet.text)
    analysis = TextBlob(tweet.text)
    polarity += analysis.sentiment.polarity
    print(analysis.sentiment)

    if(analysis.sentiment.polarity ==0):
        neutral += 1
    elif(analysis.sentiment.polarity < 0.00):
        negative += 1
    elif(analysis.sentiment.polarity > 0.00):
        positive += 1


def percentage(part, whole):
    return 100 * float(part) / float(whole)


positive = percentage(positive, no_of_search_terms)
neutral = percentage(neutral, no_of_search_terms)
negative = percentage(negative, no_of_search_terms)

positive = format(positive,'.2f')
neutral = format(neutral,'.2f')
negative = format(negative,'.2f')

## Get the observation how people are reacting to the searched keyword.

print("How people are reacting on " + search_term + " by analyzing " + str(no_of_search_terms) + " Tweets")
if(polarity == 0):
    print("Neutral")
elif(polarity < 0):
    print("Negative")
elif(polarity > 0):
    print("Positive")
# Out:
# Enter keyword to search about: accountability
# Enter the number of tweets you want to analyze: 60
# @staronline I believe an accountability transgender is thousand times better than a corrupted crook who bring so mu… https://t.co/pq22n6a6d2
# Sentiment(polarity=0.5, subjectivity=0.5)
# RT @cnnarabic: مشروع قرار جديد ضد #السعودية في #الكونغرس الأمريكي باسم "SADRA" https://t.co/4mGWOoOb5Z
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @EKminnie: “My Christianity is between me &amp; God. I don’t need to go to church or bible study. I have YouTube”
#
# LMAO. This is enemy’s #1…
# Sentiment(polarity=0.6, subjectivity=1.0)
# RT @SaintRobin911: I’m an old lady. And I’m straining my brain to recall exactly when in my 66 years people regarded pedophilia any differe…
# Sentiment(polarity=0.175, subjectivity=0.225)
# RT @jasmine_naza: Who else noticed Slice bread provokes too much accountability.
#
# Your greed can be audited in slices.
#
# But you see unslice…
# Sentiment(polarity=0.2, subjectivity=0.2)
# RT @iamhamzaabbasi: Btw, thr r many educated ppl who think accountability of Zardari &amp; NS is a drama &amp; this is all political engineering &amp;…
# Sentiment(polarity=0.25, subjectivity=0.3)
# RT @LizDavidBarrett: Wow! Ankara municipality live-streamed a public tender and &gt;160,000 tuned in to watch! That is so impressive and huge…
# Sentiment(polarity=0.375, subjectivity=0.6888888888888888)
# @JBrownSugaa Acknowledge your bad habit and change it for 30 consecutive days. Get an accountability partner who will call you out.
# Sentiment(polarity=-0.6999999999999998, subjectivity=0.6666666666666666)
# RT @SWConcern: @HumanistSW Good questions. Frontline are backed by public &amp; private interests. In the interests of public money accountabil…
# Sentiment(polarity=0.175, subjectivity=0.27708333333333335)
# We should act like this. Any Minister is a public figure and therefore should not be avoiding public "accountabilit… https://t.co/09kHSb1y05
# Sentiment(polarity=0.0, subjectivity=0.06666666666666667)
# RT @joenasandiego: Pray for your friends. Pray for friendships which will not just stay for a season but are committed to stay for a lifeti…
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @jasmine_naza: Who else noticed Slice bread provokes too much accountability.
#
# Your greed can be audited in slices.
#
# But you see unslice…
# Sentiment(polarity=0.2, subjectivity=0.2)
# RT @EUCorpReporting: India’s Ministry of Corporate Affairs is due to strengthen the rules on the #reporting of #CSR company activities to i…
# Sentiment(polarity=-0.0625, subjectivity=0.1875)
# RT @DegsyHatton: 5 billionaires owning 95% of newspaper industry will only ever print their side of the story. Mass campaign of lies and pa…
# Sentiment(polarity=0.0, subjectivity=1.0)
# RT @DegsyHatton: 5 billionaires owning 95% of newspaper industry will only ever print their side of the story. Mass campaign of lies and pa…
# Sentiment(polarity=0.0, subjectivity=1.0)
# The difference between a dream and a goal is accountability. The difference between a doer and a loafer is daily habits.
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @UCSOrtal: Nothing says "I'm innocent" like lobbying for a bill that stops people from suing you.
#
# We know Big Oil companies are hiding…
# Sentiment(polarity=0.25, subjectivity=0.39999999999999997)
# UN investigator says EU &amp; some world powers should consider cutting economic, political &amp; cultural ties with Israel… https://t.co/d5v9fYgPld
# Sentiment(polarity=-0.07499999999999998, subjectivity=0.32500000000000007)
# RT @EKminnie: “My Christianity is between me &amp; God. I don’t need to go to church or bible study. I have YouTube”
#
# LMAO. This is enemy’s #1…
# Sentiment(polarity=0.6, subjectivity=1.0)
# @IlhanMN Like we held some people that did something accountable? Those some people are your people @IlhanMN and un… https://t.co/ilOqXv9E8n
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @DegsyHatton: 5 billionaires owning 95% of newspaper industry will only ever print their side of the story. Mass campaign of lies and pa…
# Sentiment(polarity=0.0, subjectivity=1.0)
# RT @DearAuntCrabby: Trump is getting away with everything, with zero consequences of accountability.
#
# We have a child predator, a thief, an…
# Sentiment(polarity=0.0, subjectivity=0.0)
# What strikes from Mary Metcalfe's presentation thus far:
#  1) you can't hold teachers accountable for what they can'… https://t.co/5gwANqzzcL
# Sentiment(polarity=0.1, subjectivity=1.0)
# @gold123win @sue91282690 @rosemaryhopkin @ang__johnson @ann_poppy @marionste @elm_slippery @Rosenhaning… https://t.co/Z2JgU6Pdie
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @DegsyHatton: 5 billionaires owning 95% of newspaper industry will only ever print their side of the story. Mass campaign of lies and pa…
# Sentiment(polarity=0.0, subjectivity=1.0)
# RT @AJEnglish: UN investigator says the world should consider cutting ties with Israel in support of Palestinian quest for statehood https:…
# Sentiment(polarity=-0.6, subjectivity=0.9)
# RT @AJEnglish: UN investigator says the world should consider cutting ties with Israel in support of Palestinian quest for statehood https:…
# Sentiment(polarity=-0.6, subjectivity=0.9)
# RT @PalestinePR: Breaking#Thus far Israel has paid zero price for its appalling treatment of Palestinians.  In order to break the deadlock,…
# Sentiment(polarity=-0.12499999999999999, subjectivity=0.95)
# RT @jasmine_naza: Who else noticed Slice bread provokes too much accountability.
#
# Your greed can be audited in slices.
#
# But you see unslice…
# Sentiment(polarity=0.2, subjectivity=0.2)
# RT @andrew_noakes: Three reasons to join my next historical fiction group coaching class: 1) mutual support, 2) learning the craft, and 3)…
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @EksEstean: The golden thread throughout the @GTAC_PublicEcon #WinterSchool2019 in all themes seems to be accountability and implementat…
# Sentiment(polarity=0.3, subjectivity=0.5)
# RT @SaintRobin911: I’m an old lady. And I’m straining my brain to recall exactly when in my 66 years people regarded pedophilia any differe…
# Sentiment(polarity=0.175, subjectivity=0.225)
# Bipartisan senators again aim to hold Saudi Arabia accountable A group of bipartisan senators has introduced a bill… https://t.co/kfVWIPJOE9
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @BigElad: "'Attorney General Schmitt might want to ask himself why he isn’t doing anything to hold public officials responsible for thei…
# Sentiment(polarity=0.08333333333333333, subjectivity=0.37222222222222223)
# RT @drdeblk: Powerful rich men like #Epstein and #Trump are completely shielded from accountability in US. @SecretaryAcosta is part of this…
# Sentiment(polarity=0.25833333333333336, subjectivity=0.7166666666666667)
# Bullet accountability: how to upgrade yourself in 2-minutes per day https://t.co/D6QuwjF5lQ
# Sentiment(polarity=0.0, subjectivity=0.0)
# @T_Maduva @InfoMinZW @edmnangagwa Chief it not only about our pennies remember we have also gained a lot of skills… https://t.co/EdrJeba15y
# Sentiment(polarity=0.0, subjectivity=1.0)
# RT @ahmednasirlaw: 1/1.The fortunes of the  Kenyan Judiciary in the past 3 yrs under the ABLE leadership of CJ Maraga has taken a battering…
# Sentiment(polarity=0.125, subjectivity=0.4375)
# RT @jasmine_naza: Who else noticed Slice bread provokes too much accountability.
#
# Your greed can be audited in slices.
#
# But you see unslice…
# Sentiment(polarity=0.2, subjectivity=0.2)
# RT @ahmednasirlaw: 1/1.The fortunes of the  Kenyan Judiciary in the past 3 yrs under the ABLE leadership of CJ Maraga has taken a battering…
# Sentiment(polarity=0.125, subjectivity=0.4375)
# RT @icazicaz: "The Accrual IPSAS based Accounting framework will assist in Reporting, Accountability and Transparency." Mr Churu
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @iimcomic: If only news channels cared so much about the accountability when it comes to national tragedies where people die. https://t.…
# Sentiment(polarity=0.1, subjectivity=0.6)
# RT @Jan_Achakzai: Another video, for another accountability judge?
#
# But She will never answer forgery charges to court.
# Law is for the we…
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @iamhamzaabbasi: Btw, thr r many educated ppl who think accountability of Zardari &amp; NS is a drama &amp; this is all political engineering &amp;…
# Sentiment(polarity=0.25, subjectivity=0.3)
# Through our Destabilising Heteronormativity project, https://t.co/Zx8JqaZuDk, we partnered with @HouseOfRainbow and… https://t.co/IvjoWF9S3K
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @yourfeminstboss: The blame always ends up back on women - somehow, someway, men always make themselves out to be the victims (when they…
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @Jan_Achakzai: Another video, for another accountability judge?
#
# But She will never answer forgery charges to court.
# Law is for the we…
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @RAICESTEXAS: The hearing will examine the impact of the Trump Admin's deterrence policies on the humanitarian crisis at the border, rec…
# Sentiment(polarity=0.0, subjectivity=0.0)
# @nytimes Take a bow, Sir.  It is not rare to have bold and grounded people in the bureaucracy.  It is just that a h… https://t.co/gyLDDQIrCL
# Sentiment(polarity=0.09166666666666666, subjectivity=0.7833333333333333)
# RT @ManlnTheHoody: u can be mad at acosta for letting a sexual predator avoid accountability. and u should be. as long as u understand that…
# Sentiment(polarity=-0.05833333333333333, subjectivity=0.7444444444444445)
# RT @DearAuntCrabby: Trump is getting away with everything, with zero consequences of accountability.
#
# We have a child predator, a thief, an…
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @_petermason: In the coverage so far this morning, not a single Labour Party frontbencher or NEC member has spoken, and certainly not ta…
# Sentiment(polarity=0.009523809523809532, subjectivity=0.5952380952380952)
# RT @DaaruBaazMehta: READ N SHARE
#
# @AkshayMarathe writes about @ArvindKejriwal Govt's CCTV project in Delhi Govt School classrooms
#
# These ca…
# Sentiment(polarity=0.0, subjectivity=0.0)
# India’s Ministry of Corporate Affairs is due to strengthen the rules on the #reporting of #CSR company activities t… https://t.co/JGF3qhPD9Y
# Sentiment(polarity=-0.0625, subjectivity=0.1875)
# RT @iimcomic: If only news channels cared so much about the accountability when it comes to national tragedies where people die. https://t.…
# Sentiment(polarity=0.1, subjectivity=0.6)
# #Eritrea: "The same government which a Council mandated special mechanism deemed responsible for crimes against hum… https://t.co/zoncjeHg2U
# Sentiment(polarity=0.18571428571428572, subjectivity=0.4154761904761905)
# RT @MpumalangaSave: Uranium from abandoned gold mines are linked to heavy metal poisoning and is radioactive. Once released into the enviro…
# Sentiment(polarity=-0.2, subjectivity=0.5)
# UN official devises blueprint for Israeli accountability @AJENews  https://t.co/qrM9SgLC6A
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @benabyad: "Michael Lynk, an independent UN researcher, said the European Union (EU) and some world powers should consider cutting econo…
# Sentiment(polarity=-0.19999999999999998, subjectivity=0.3416666666666666)
# RT @DearAuntCrabby: Trump is getting away with everything, with zero consequences of accountability.
#
# We have a child predator, a thief, an…
# Sentiment(polarity=0.0, subjectivity=0.0)
# How people are reacting on accountability by analyzing 60 Tweets
# Positive
